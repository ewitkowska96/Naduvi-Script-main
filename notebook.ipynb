# %%
import Naduvi

# %%
Naduvi.case_wuunder()
# Out:
#    numCDEClient              nom_dest                       ad1_dest cp_dest  \
# 0      25503-01    Mirjam Van Coillie     Doktersklappe 2 21 5 Stock   26135
# 1      25540-01              Anna Mai            Westbahnhofstraße 3   07745
# 2      25768-01        Claudia Enning               Maikottenweg 136   48155
# 3      25868-01       Adrienne Klepel              Malterstrasse  32   01159
# 4      25922-01            Bianca Ely                    Am Groen 21   12683
# 5      26059-01          Sifa Catkili              Kastellstraße  14   74906
# 6      26063-01  Antje Arnold-Beutel   Über den Krautländern 23  23B   99098
# 7      26160-01    Lucian Holtwiesche                 Kronengasse 12   50667
# 8      26220-01      Bernd Neuerburg              Steinbornerstr  14   54550
# 9      26252-01           Marco Nowak                 Am Kleeberg 27   16356
# 10     26268-01     Louise Injarabian                Ritterstrasse 1   50668
# ...

# %%
Naduvi.case_ambro()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\Witkowska.Ewa\Desktop\Naduvi script\notebook.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Witkowska.Ewa/Desktop/Naduvi%20script/notebook.ipynb#ch0000002?line=0'>1</a> Naduvi.case_ambro()
#
# File c:\Users\Witkowska.Ewa\Desktop\Naduvi script\Naduvi.py:118, in case_ambro()
#     115 #Add insurance of the package
#     116 final['Ubezpieczenie'] = final.apply(currency_convertor, axis=1).round()
# --> 118 #Save to excel file
#     119 final.to_excel('import file-ambro ' + today + '.xlsx', sheet_name='exported-data', index=None, engine='openpyxl')
#     121 return final
#
# ...
